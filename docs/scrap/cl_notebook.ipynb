# %%
import requests

# %%
url = "https://www.courtlistener.com/api/rest/v4/search/?q=apple+samsung"
headers = {"Authorization": "Token 4cd64f7c2c009657cfa3133893d1cd846cfa7050"}

resp = requests.get(url, headers=headers)
# resp.raise_for_status()
print(resp)
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data
# Out:
# {'count': 645,
#  'next': 'https://www.courtlistener.com/api/rest/v4/search/?cursor=cz0xMTYuODM5ODImcz04NzE4NTcwJnQ9byZkPTIwMjUtMDktMjQmcD0y&q=apple+samsung',
#  'previous': None,
#  'results': [{'absolute_url': '/opinion/9335076/samsung-elecs-co-v-apple-inc/',
#    'attorney': '',
#    'caseName': 'Samsung Elecs. Co. v. Apple Inc.',
#    'caseNameFull': 'SAMSUNG ELECTRONICS CO., LTD. v. APPLE INC.',
#    'citation': ['138 S. Ct. 420', '199 L. Ed. 2d 311'],
#    'citeCount': 0,
#    'cluster_id': 9335076,
#    'court': 'Supreme Court of the United States',
#    'court_citation_string': 'SCOTUS',
#    'court_id': 'scotus',
#    'dateArgued': None,
#    'dateFiled': '2017-11-06',
#    'dateReargued': None,
#    'dateReargumentDenied': None,
#    'docketNumber': 'No. 16–1102.',
#    'docket_id': 66644947,
#    'judge': '',
#    'lexisCite': '',
#    'meta': {'timestamp': '2024-06-23T00:50:08.752010Z',
#     'date_created': '2022-12-15T20:59:57.545610Z',
# ...

# %%
print(data.keys())
res = data["results"]
print(len(res))
res[0]
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])
# 20
# {'absolute_url': '/opinion/9335076/samsung-elecs-co-v-apple-inc/',
#  'attorney': '',
#  'caseName': 'Samsung Elecs. Co. v. Apple Inc.',
#  'caseNameFull': 'SAMSUNG ELECTRONICS CO., LTD. v. APPLE INC.',
#  'citation': ['138 S. Ct. 420', '199 L. Ed. 2d 311'],
#  'citeCount': 0,
#  'cluster_id': 9335076,
#  'court': 'Supreme Court of the United States',
#  'court_citation_string': 'SCOTUS',
#  'court_id': 'scotus',
#  'dateArgued': None,
#  'dateFiled': '2017-11-06',
#  'dateReargued': None,
#  'dateReargumentDenied': None,
#  'docketNumber': 'No. 16–1102.',
#  'docket_id': 66644947,
#  'judge': '',
#  'lexisCite': '',
#  'meta': {'timestamp': '2024-06-23T00:50:08.752010Z',
#   'date_created': '2022-12-15T20:59:57.545610Z',
#   'score': {'bm25': 137.56883}},
#  'neutralCite': '',
#  'non_participating_judge_ids': [],
#  'opinions': [{'author_id': None,
#    'cites': [],
#    'download_url': None,
#    'id': 9330414,
# ...

# %%
for d in res:
    url = d.get("download_url")
    print(url)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
url = "https://www.courtlistener.com/api/rest/v4/opinion/8722490/"
headers = {"Authorization": "Token 4cd64f7c2c009657cfa3133893d1cd846cfa7050"}

resp = requests.get(url, headers=headers)
# resp.raise_for_status()
print(resp)
# Out:
# <Response [404]>

# %%
sample_docket = data["results"][0]

# %%
sample_docket
# Out:
# {'absolute_url': '/opinion/7326041/apple-inc-v-samsung-electronics-co/',
# ...

# %%
# url = "https://www.courtlistener.com/api/rest/v4/clusters/"
print(data.keys())
res = data["results"]
print(len(res))
print(res)
# print(data["results"][0])

print(data["results"][0]["plain_text"][:500])
print(data["results"][0]["id"])
# print(data["results"][0]["plain_text"])
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])
# 20
# ...

# %%
example_doc = data["results"][0]
print(example_doc.keys())

# %%
print(example_doc['absolute_url'])

# %%
abs_url = example_doc['absolute_url']

# %%
abs_url.split('/')[-2]

# %%
# Out:
# 403
# {'detail': 'You do not have permission to perform this action.'}
